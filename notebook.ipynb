# %%
import pandas as pandas
df= pandas.read_csv("D:\MutiAgent Cybersecurity\data\processed\cleaned_dataset.csv")
print("Shape: ", df.shape)
print(df["Label"].value_counts())
# Out:
# Shape:  (2658719, 79)
# Label
# BENIGN                        2200296
# DoS Hulk                       175476
# DDoS                           128022
# PortScan                       120121
# DoS GoldenEye                   10286
# FTP-Patator                      6049
# DoS slowloris                    5439
# DoS Slowhttptest                 5228
# SSH-Patator                      3642
# Bot                              1956
# Web Attack - Brute Force         1484
# Web Attack - XSS                  652
# Infiltration                       36
# Web Attack - Sql Injection         21
# Heartbleed                         11
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np

df= pd.read_csv("D:\MutiAgent Cybersecurity\data\processed\sampled_dataset.csv")
print("Shape: ", df.shape)

attack_df= df[df["Label"]!="BENIGN"].copy()
print(" attack df Shape: ", attack_df.shape)
print(df["Label"].value_counts())
# Out:
# Shape:  (50000, 80)
#  attack df Shape:  (25000, 80)
# Label
# BENIGN                        25000
# DoS Hulk                       7939
# DDoS                           5927
# PortScan                       5593
# DoS GoldenEye                   936
# FTP-Patator                     756
# DoS slowloris                   731
# DoS Slowhttptest                722
# SSH-Patator                     654
# Bot                             583
# Web Attack - Brute Force        563
# Web Attack - XSS                528
# Infiltration                     36
# Web Attack - Sql Injection       21
# Heartbleed                       11
# Name: count, dtype: int64
